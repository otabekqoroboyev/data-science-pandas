# %% [markdown]
# <a href="https://colab.research.google.com/github/otabekqoroboyev/data-science-pandas/blob/main/arifmetik_amallar_pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=['a', 'c', 'e', 'f', 'g'])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# E'tibor bering, `s1` da mavjud `d` indeksi `s2`da mavjud bo'lmaganligi sabab `s1+s2` da `d` indeksdagi qiymat `NaN` bo'ldi.

# %%
df1 = pd.DataFrame(np.arange(9.).reshape(3,3), columns=list('bcd'), index=['Olma','Anor','Uzum'])
df2 = pd.DataFrame(np.arange(12.).reshape(4,3), columns=list('abc'), index=['Olma','Anor','Qovun','Anjir'])

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %%
df1+df2
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN  7.0  9.0 NaN
# Olma  NaN  1.0  3.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %% [markdown]
# `a` va `d` ustunlar hamda `Qovun` va `Anjir` qatorlar ikkala `DataFrame`da bo'lmagani sababli yuqoridagi natija chiqdi

# %%
df1.add(df2)
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN  7.0  9.0 NaN
# Olma  NaN  1.0  3.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %% [markdown]
# Bunda maxsus `fill_value` parametri yordamida mos tushuvchi indekslardagi NaN qiymatlarni boshqa qiymat bilan almashtirish mumkin. Bu usulda yakuniy natijada ikkala df da ham mavjud bo'lmagan indekslarda `NaN` qiymati qoladi.

# %%
df2.add(df1, fill_value=0)
# Out:
#          a     b     c    d
# Anjir  9.0  10.0  11.0  NaN
# Anor   3.0   7.0   9.0  5.0
# Olma   0.0   1.0   3.0  2.0
# Qovun  6.0   7.0   8.0  NaN
# Uzum   NaN   6.0   7.0  8.0

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %% [markdown]
# ### Boshqa arifmetik amallar
#
# - `add`, `radd` - Qo'shish (+)
# - `sub`, `rsub` - Ayirish (-)
# - `div`, `rdiv` - Bo'lish (/)
# - `floordiv`, `rfloordiv` - Bo'lish va butun qismini olis (//)
# - `mul`, `rmul` - Ko'paytirish (*)
# - `pow`, `rpow` - Eksponenta (\*\*)
#
# Yuqoridagi amallarning barchasida `fill_value` parametri mavjud.

# %% [markdown]
# `r`bilan boshlangan metodlarda `DataFrame` ifodaning o'ng  tarafida bo'ladi.

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df1.sub(2) # df-2 degani
# Out:
#         b    c    d
# Olma -2.0 -1.0  0.0
# Anor  1.0  2.0  3.0
# Uzum  4.0  5.0  6.0

# %%
df2.rsub(2) # 2-df degani
# Out:
#          a    b    c
# Olma   2.0  1.0  0.0
# Anor  -1.0 -2.0 -3.0
# Qovun -4.0 -5.0 -6.0
# Anjir -7.0 -8.0 -9.0

# %% [markdown]
# ## `DataFrame` va `Series` o'rtasida arifmetik amallar

# %%
df = pd.DataFrame(np.arange(1,13.).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0   2.0    3.0    4.0
# b   5.0   6.0    7.0    8.0
# c   9.0  10.0   11.0   12.0

# %%
obj = pd.Series([1,1,2,2], index=df.columns)
obj
# Out:
# Olma     1
# Anor     1
# Qovun    2
# Anjir    2
# dtype: int64

# %%
df-obj
# Out:
#    Olma  Anor  Qovun  Anjir
# a   0.0   1.0    1.0    2.0
# b   4.0   5.0    5.0    6.0
# c   8.0   9.0    9.0   10.0

# %%
obj = pd.Series([2,3,1], index=['Olma','Uzum','Qovun'])
obj
# Out:
# Olma     2
# Uzum     3
# Qovun    1
# dtype: int64

# %%
df+obj
# Out:
#    Anjir  Anor  Olma  Qovun  Uzum
# a    NaN   NaN   3.0    4.0   NaN
# b    NaN   NaN   7.0    8.0   NaN
# c    NaN   NaN  11.0   12.0   NaN

# %%
df-obj['Olma']
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -1.0   0.0    1.0    2.0
# b   3.0   4.0    5.0    6.0
# c   7.0   8.0    9.0   10.0

# %%
df.add(obj['Qovun'])
# Out:
#    Olma  Anor  Qovun  Anjir
# a   2.0   3.0    4.0    5.0
# b   6.0   7.0    8.0    9.0
# c  10.0  11.0   12.0   13.0

# %% [markdown]
# ## pandas Obyekti elementlariga Funksiyalarni qo'llash

# %%
df = pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.402282 -0.070571 -0.985054  0.746720
# b  1.808396 -1.481601  0.877492 -0.486892
# c -0.029116 -1.912463 -1.104636  0.642761

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.402282  0.070571  0.985054  0.746720
# b  1.808396  1.481601  0.877492  0.486892
# c  0.029116  1.912463  1.104636  0.642761

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0  -0.0   -1.0    1.0
# b   2.0  -1.0    1.0   -0.0
# c  -0.0  -2.0   -1.0    1.0

# %%
df.mean()
# Out:
# Olma     1.060521
# Anor    -1.154878
# Qovun   -0.404066
# Anjir    0.300863
# dtype: float64

# %% [markdown]
# Yuqoridagi funksiyalarni `.apply()` metodi yordamida ham qo'llash mumkin.

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.402282 -0.070571 -0.985054  0.746720
# b  1.808396 -1.481601  0.877492 -0.486892
# c -0.029116 -1.912463 -1.104636  0.642761

# %%
df.apply(np.mean)
# Out:
# Olma     1.060521
# Anor    -1.154878
# Qovun   -0.404066
# Anjir    0.300863
# dtype: float64

# %% [markdown]
# `.apply()` yordamida funksiyani ustun yoki qatorga qo'llashni ko'rsatishimiz mumkin

# %%
df.apply(np.sum, axis="columns")
# Out:
# a    1.093376
# b    0.717395
# c   -2.403454
# dtype: float64

# %% [markdown]
# Bu metodning afzalligi, o'zingiz istalgan funksiyani yozib uni DF elementlariga qo'llashigniz mumkin:

# %%
# DF qatori max va min qiymati ayirmasini hisoblaydigan funksiya
f = lambda x: x.max() - x.min()

# %%
df.apply(f)
# Out:
# Olma     1.837512
# Anor     1.841893
# Qovun    1.982128
# Anjir    1.233612
# dtype: float64

# %% [markdown]
# Funksiya nafaqat yagona qiymat, balki series obyektini ham qaytarishi mumkin

# %%
def foo(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun     Anjir
# min -0.029116 -1.912463 -1.104636 -0.486892
# max  1.808396 -0.070571  0.877492  0.746720

# %% [markdown]
# Biror funksiyani DF har bir elementiga alohida qo'llash uchun `.applymap()` metodidan foydalaning.

# %%
f = lambda x : x*x # qiymatni kvadratga oshiruvchi funksiya

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     2      3      4
# b     5     6      7      8
# c     9    10     11     12

# %%
df.applymap(f)
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     4      9     16
# b    25    36     49     64
# c    81   100    121    144

# %% [markdown]
# ## Tartiblash va Reytinglash
