# %% [markdown]
# <a href="https://colab.research.google.com/github/otabekqoroboyev/data-science-pandas/blob/main/dataFrame_pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
data = {
    'yil':[2021,2020,2019,2017,2016,2015,2010],
    'aholi soni' : [33.9,33.6,32.6,32.5,32,31.4,30.7],
    "temp" : [1.26, 1.6, 1.8, 1.1, 1.9, 1.2, 1.5]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     yil  aholi soni  temp
# 0  2021        33.9  1.26
# 1  2020        33.6  1.60
# 2  2019        32.6  1.80
# 3  2017        32.5  1.10
# 4  2016        32.0  1.90
# 5  2015        31.4  1.20
# 6  2010        30.7  1.50

# %%
df.head()
# Out:
#     yil  aholi soni  temp
# 0  2021        33.9  1.26
# 1  2020        33.6  1.60
# 2  2019        32.6  1.80
# 3  2017        32.5  1.10
# 4  2016        32.0  1.90

# %%
#hohglagancha qiymat olish uchun
df.head(2)
# Out:
#     yil  aholi soni  temp
# 0  2021        33.9  1.26
# 1  2020        33.6  1.60

# %%
df.shape # o'lchamini bilish uchun
# Out:
# (7, 3)

# %% [markdown]
# # DataFrame ustunlar

# %%
df = pd.DataFrame(data, columns=['yil','temp','aholi soni'])

# %%
df
# Out:
#     yil  temp  aholi soni
# 0  2021  1.26        33.9
# 1  2020  1.60        33.6
# 2  2019  1.80        32.6
# 3  2017  1.10        32.5
# 4  2016  1.90        32.0
# 5  2015  1.20        31.4
# 6  2010  1.50        30.7

# %%
df = pd.DataFrame(data, columns=['yil','temp','aholi soni', 'YAIM'])

# %%
df
# Out:
#     yil  temp  aholi soni YAIM
# 0  2021  1.26        33.9  NaN
# 1  2020  1.60        33.6  NaN
# 2  2019  1.80        32.6  NaN
# 3  2017  1.10        32.5  NaN
# 4  2016  1.90        32.0  NaN
# 5  2015  1.20        31.4  NaN
# 6  2010  1.50        30.7  NaN

# %%
df = pd.DataFrame(data, columns=['yil','temp','aholi soni', 'YAIM'], index=['bir',2,3,4,5,6,7])

# %%
df
# Out:
#       yil  temp  aholi soni YAIM
# bir  2021  1.26        33.9  NaN
# 2    2020  1.60        33.6  NaN
# 3    2019  1.80        32.6  NaN
# 4    2017  1.10        32.5  NaN
# 5    2016  1.90        32.0  NaN
# 6    2015  1.20        31.4  NaN
# 7    2010  1.50        30.7  NaN

# %%
aholi = df['aholi soni']

# %%
aholi
# Out:
# bir    33.9
# 2      33.6
# 3      32.6
# 4      32.5
# 5      32.0
# 6      31.4
# 7      30.7
# Name: aholi soni, dtype: float64

# %%
type(aholi)
# Out:
# pandas.core.series.Series

# %%
df.temp
# Out:
# bir    1.26
# 2      1.60
# 3      1.80
# 4      1.10
# 5      1.90
# 6      1.20
# 7      1.50
# Name: temp, dtype: float64

# %%
df
# Out:
#       yil  temp  aholi soni YAIM
# bir  2021  1.26        33.9  NaN
# 2    2020  1.60        33.6  NaN
# 3    2019  1.80        32.6  NaN
# 4    2017  1.10        32.5  NaN
# 5    2016  1.90        32.0  NaN
# 6    2015  1.20        31.4  NaN
# 7    2010  1.50        30.7  NaN

# %%
df.YAIM = 0

# %%
df
# Out:
#       yil  temp  aholi soni  YAIM
# bir  2021  1.26        33.9     0
# 2    2020  1.60        33.6     0
# 3    2019  1.80        32.6     0
# 4    2017  1.10        32.5     0
# 5    2016  1.90        32.0     0
# 6    2015  1.20        31.4     0
# 7    2010  1.50        30.7     0

# %%
val = pd.Series([1700,1650,1790], index=["bir",2,7]) # index qiymat kiritish
df.YAIM = val

# %%
df
# Out:
#       yil  temp  aholi soni    YAIM
# bir  2021  1.26        33.9  1700.0
# 2    2020  1.60        33.6  1650.0
# 3    2019  1.80        32.6     NaN
# 4    2017  1.10        32.5     NaN
# 5    2016  1.90        32.0     NaN
# 6    2015  1.20        31.4     NaN
# 7    2010  1.50        30.7  1790.0

# %%
 val = [1700,1600,1500,1400,1300,1200,1100]
 df['YAIM'] = val

# %%
df
# Out:
#       yil  temp  aholi soni  YAIM
# bir  2021  1.26        33.9  1700
# 2    2020  1.60        33.6  1600
# 3    2019  1.80        32.6  1500
# 4    2017  1.10        32.5  1400
# 5    2016  1.90        32.0  1300
# 6    2015  1.20        31.4  1200
# 7    2010  1.50        30.7  1100

# %%
df['1500+'] = df.YAIM>1500

# %%
df
# Out:
#       yil  temp  aholi soni  YAIM  1500+
# bir  2021  1.26        33.9  1700   True
# 2    2020  1.60        33.6  1600   True
# 3    2019  1.80        32.6  1500  False
# 4    2017  1.10        32.5  1400  False
# 5    2016  1.90        32.0  1300  False
# 6    2015  1.20        31.4  1200  False
# 7    2010  1.50        30.7  1100  False

# %%
# o'chirish ustunlarni 
del df['1500+']

# %%
df
# Out:
#       yil  temp  aholi soni  YAIM
# bir  2021  1.26        33.9  1700
# 2    2020  1.60        33.6  1600
# 3    2019  1.80        32.6  1500
# 4    2017  1.10        32.5  1400
# 5    2016  1.90        32.0  1300
# 6    2015  1.20        31.4  1200
# 7    2010  1.50        30.7  1100

# %%
data = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name = 'Yil'

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2 = pd.DataFrame(data, index=[2021,2019,2017]) #bizga kerak bo'ladigan yillar  
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df2.T # ustun va qatorni almashtirish uchun
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
arr = df2.values # array olish uchun va saqlab qolish arr qilib

# %%
type(arr) # turi
# Out:
# numpy.ndarray
